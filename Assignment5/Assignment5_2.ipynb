# %% [markdown]
# <a href="https://colab.research.google.com/github/saicharan-r/EIP4/blob/master/Assignment5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/hvc_data.zip"
# look for `hvc_annotations.csv` file and `resized` dir
# %ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# replace resized/9733.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16, InceptionV3, ResNet50
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import keras
import numpy as np

def get_random_eraser(p=1, w=25, h=25, v_l=0, v_h=1, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser


# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True, augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation=augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }
        return image/255.0, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 9109    resized/9110.jpg              1  ...                        0              1
# 10851  resized/10853.jpg              0  ...                        1              0
# 9790    resized/9791.jpg              0  ...                        1              0
# 13173  resized/13175.jpg              1  ...                        0              1
# 5564    resized/5565.jpg              0  ...                        1              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, batch_size=32, augmentation=ImageDataGenerator(horizontal_flip=True, preprocessing_function=get_random_eraser()))
valid_gen = PersonDataGenerator(val_df, batch_size=64, shuffle=False)

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
backbone = InceptionV3(include_top = False, weights = None,
  input_tensor=Input(shape=(224, 224, 3)),
)

neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = Dropout(0.2)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.3)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# freeze backbone
for layer in backbone.layers:
	layer.trainable = False

# %%
# losses = {
# 	"gender_output": "binary_crossentropy",
# 	"image_quality_output": "categorical_crossentropy",
# 	"age_output": "categorical_crossentropy",
# 	"weight_output": "categorical_crossentropy",

# }
# loss_weights = {"gender_output": 1.0, "image_quality_output": 1.0, "age_output": 1.0}
opt = SGD(lr=0.001, momentum=0.9)
model.compile(
    optimizer=opt,
    loss="categorical_crossentropy", 
    # loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)

# %%
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6,
    epochs=30,
    verbose=1
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/30
# 359/360 [============================>.] - ETA: 0s - loss: 8.1777 - gender_output_loss: 0.7040 - image_quality_output_loss: 1.0036 - age_output_loss: 1.4780 - weight_output_loss: 1.0398 - bag_output_loss: 0.9646 - footwear_output_loss: 1.0646 - pose_output_loss: 0.9643 - emotion_output_loss: 0.9588 - gender_output_acc: 0.5472 - image_quality_output_acc: 0.5415 - age_output_acc: 0.3840 - weight_output_acc: 0.6256 - bag_output_acc: 0.5388 - footwear_output_acc: 0.4466 - pose_output_acc: 0.6103 - emotion_output_acc: 0.7100
# 360/360 [==============================] - 64s 178ms/step - loss: 8.1765 - gender_output_loss: 0.7039 - image_quality_output_loss: 1.0036 - age_output_loss: 1.4777 - weight_output_loss: 1.0388 - bag_output_loss: 0.9643 - footwear_output_loss: 1.0645 - pose_output_loss: 0.9643 - emotion_output_loss: 0.9595 - gender_output_acc: 0.5473 - image_quality_output_acc: 0.5415 - age_output_acc: 0.3841 - weight_output_acc: 0.6261 - bag_output_acc: 0.5391 - footwear_output_acc: 0.4468 - pose_output_acc: 0.6102 - emotion_output_acc: 0.7098 - val_loss: 9.0512 - val_gender_output_loss: 0.6904 - val_image_quality_output_loss: 1.0698 - val_age_output_loss: 1.5770 - val_weight_output_loss: 1.2868 - val_bag_output_loss: 1.0496 - val_footwear_output_loss: 1.0850 - val_pose_output_loss: 1.0417 - val_emotion_output_loss: 1.2508 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 2/30
# 360/360 [==============================] - 56s 154ms/step - loss: 7.9665 - gender_output_loss: 0.6857 - image_quality_output_loss: 0.9813 - age_output_loss: 1.4417 - weight_output_loss: 1.0116 - bag_output_loss: 0.9338 - footwear_output_loss: 1.0336 - pose_output_loss: 0.9406 - emotion_output_loss: 0.9383 - gender_output_acc: 0.5520 - image_quality_output_acc: 0.5551 - age_output_acc: 0.3984 - weight_output_acc: 0.6354 - bag_output_acc: 0.5590 - footwear_output_acc: 0.4684 - pose_output_acc: 0.6176 - emotion_output_acc: 0.7125 - val_loss: 8.7035 - val_gender_output_loss: 0.6874 - val_image_quality_output_loss: 1.0455 - val_age_output_loss: 1.5454 - val_weight_output_loss: 1.2026 - val_bag_output_loss: 1.0107 - val_footwear_output_loss: 1.0707 - val_pose_output_loss: 1.0015 - val_emotion_output_loss: 1.1397 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 3/30
# 360/360 [==============================] - 55s 153ms/step - loss: 7.9116 - gender_output_loss: 0.6846 - image_quality_output_loss: 0.9791 - age_output_loss: 1.4368 - weight_output_loss: 1.0040 - bag_output_loss: 0.9242 - footwear_output_loss: 1.0207 - pose_output_loss: 0.9377 - emotion_output_loss: 0.9246 - gender_output_acc: 0.5582 - image_quality_output_acc: 0.5560 - age_output_acc: 0.3990 - weight_output_acc: 0.6352 - bag_output_acc: 0.5595 - footwear_output_acc: 0.4808 - pose_output_acc: 0.6175 - emotion_output_acc: 0.7122 - val_loss: 8.4555 - val_gender_output_loss: 0.6849 - val_image_quality_output_loss: 1.0293 - val_age_output_loss: 1.5225 - val_weight_output_loss: 1.1353 - val_bag_output_loss: 0.9853 - val_footwear_output_loss: 1.0600 - val_pose_output_loss: 0.9776 - val_emotion_output_loss: 1.0604 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 4/30
# 360/360 [==============================] - 54s 151ms/step - loss: 7.8638 - gender_output_loss: 0.6817 - image_quality_output_loss: 0.9758 - age_output_loss: 1.4313 - weight_output_loss: 0.9953 - bag_output_loss: 0.9240 - footwear_output_loss: 1.0064 - pose_output_loss: 0.9326 - emotion_output_loss: 0.9167 - gender_output_acc: 0.5615 - image_quality_output_acc: 0.5562 - age_output_acc: 0.3996 - weight_output_acc: 0.6352 - bag_output_acc: 0.5579 - footwear_output_acc: 0.4972 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7121 - val_loss: 8.2860 - val_gender_output_loss: 0.6846 - val_image_quality_output_loss: 1.0178 - val_age_output_loss: 1.5037 - val_weight_output_loss: 1.0886 - val_bag_output_loss: 0.9666 - val_footwear_output_loss: 1.0543 - val_pose_output_loss: 0.9605 - val_emotion_output_loss: 1.0097 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 5/30
# 360/360 [==============================] - 53s 148ms/step - loss: 7.8575 - gender_output_loss: 0.6795 - image_quality_output_loss: 0.9759 - age_output_loss: 1.4320 - weight_output_loss: 0.9952 - bag_output_loss: 0.9235 - footwear_output_loss: 1.0047 - pose_output_loss: 0.9315 - emotion_output_loss: 0.9151 - gender_output_acc: 0.5643 - image_quality_output_acc: 0.5562 - age_output_acc: 0.3997 - weight_output_acc: 0.6352 - bag_output_acc: 0.5589 - footwear_output_acc: 0.5057 - pose_output_acc: 0.6176 - emotion_output_acc: 0.7121 - val_loss: 8.1022 - val_gender_output_loss: 0.6841 - val_image_quality_output_loss: 1.0102 - val_age_output_loss: 1.4786 - val_weight_output_loss: 1.0375 - val_bag_output_loss: 0.9423 - val_footwear_output_loss: 1.0495 - val_pose_output_loss: 0.9441 - val_emotion_output_loss: 0.9559 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 6/30
# 359/360 [============================>.] - ETA: 0s - loss: 7.8145 - gender_output_loss: 0.6790 - image_quality_output_loss: 0.9691 - age_output_loss: 1.4292 - weight_output_loss: 0.9879 - bag_output_loss: 0.9214 - footwear_output_loss: 0.9921 - pose_output_loss: 0.9301 - emotion_output_loss: 0.9058 - gender_output_acc: 0.5629 - image_quality_output_acc: 0.5564 - age_output_acc: 0.3997 - weight_output_acc: 0.6355 - bag_output_acc: 0.5596 - footwear_output_acc: 0.5152 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7128Epoch 6/30
# 360/360 [==============================] - 55s 152ms/step - loss: 7.8156 - gender_output_loss: 0.6791 - image_quality_output_loss: 0.9690 - age_output_loss: 1.4294 - weight_output_loss: 0.9880 - bag_output_loss: 0.9213 - footwear_output_loss: 0.9922 - pose_output_loss: 0.9303 - emotion_output_loss: 0.9063 - gender_output_acc: 0.5628 - image_quality_output_acc: 0.5564 - age_output_acc: 0.3997 - weight_output_acc: 0.6352 - bag_output_acc: 0.5601 - footwear_output_acc: 0.5150 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7125 - val_loss: 8.0089 - val_gender_output_loss: 0.6833 - val_image_quality_output_loss: 1.0072 - val_age_output_loss: 1.4604 - val_weight_output_loss: 1.0111 - val_bag_output_loss: 0.9312 - val_footwear_output_loss: 1.0505 - val_pose_output_loss: 0.9348 - val_emotion_output_loss: 0.9305 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 7/30
# 360/360 [==============================] - 54s 149ms/step - loss: 7.8042 - gender_output_loss: 0.6782 - image_quality_output_loss: 0.9699 - age_output_loss: 1.4274 - weight_output_loss: 0.9849 - bag_output_loss: 0.9169 - footwear_output_loss: 0.9933 - pose_output_loss: 0.9284 - emotion_output_loss: 0.9052 - gender_output_acc: 0.5670 - image_quality_output_acc: 0.5560 - age_output_acc: 0.3994 - weight_output_acc: 0.6352 - bag_output_acc: 0.5615 - footwear_output_acc: 0.5077 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7123 - val_loss: 7.9431 - val_gender_output_loss: 0.6826 - val_image_quality_output_loss: 1.0064 - val_age_output_loss: 1.4448 - val_weight_output_loss: 0.9899 - val_bag_output_loss: 0.9211 - val_footwear_output_loss: 1.0528 - val_pose_output_loss: 0.9294 - val_emotion_output_loss: 0.9161 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 8/30
# 360/360 [==============================] - 54s 150ms/step - loss: 7.7803 - gender_output_loss: 0.6773 - image_quality_output_loss: 0.9661 - age_output_loss: 1.4229 - weight_output_loss: 0.9797 - bag_output_loss: 0.9157 - footwear_output_loss: 0.9901 - pose_output_loss: 0.9266 - emotion_output_loss: 0.9019 - gender_output_acc: 0.5646 - image_quality_output_acc: 0.5558 - age_output_acc: 0.3991 - weight_output_acc: 0.6351 - bag_output_acc: 0.5602 - footwear_output_acc: 0.5131 - pose_output_acc: 0.6175 - emotion_output_acc: 0.7123 - val_loss: 7.9233 - val_gender_output_loss: 0.6821 - val_image_quality_output_loss: 1.0089 - val_age_output_loss: 1.4370 - val_weight_output_loss: 0.9838 - val_bag_output_loss: 0.9174 - val_footwear_output_loss: 1.0543 - val_pose_output_loss: 0.9285 - val_emotion_output_loss: 0.9112 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 8/30
# Epoch 9/30
# 359/360 [============================>.] - ETA: 0s - loss: 7.7883 - gender_output_loss: 0.6811 - image_quality_output_loss: 0.9651 - age_output_loss: 1.4213 - weight_output_loss: 0.9783 - bag_output_loss: 0.9145 - footwear_output_loss: 0.9979 - pose_output_loss: 0.9260 - emotion_output_loss: 0.9040 - gender_output_acc: 0.5717 - image_quality_output_acc: 0.5568 - age_output_acc: 0.3999 - weight_output_acc: 0.6360 - bag_output_acc: 0.5635 - footwear_output_acc: 0.5060 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7117Epoch 9/30
# 360/360 [==============================] - 55s 153ms/step - loss: 7.7882 - gender_output_loss: 0.6811 - image_quality_output_loss: 0.9655 - age_output_loss: 1.4214 - weight_output_loss: 0.9785 - bag_output_loss: 0.9144 - footwear_output_loss: 0.9979 - pose_output_loss: 0.9264 - emotion_output_loss: 0.9029 - gender_output_acc: 0.5718 - image_quality_output_acc: 0.5564 - age_output_acc: 0.3996 - weight_output_acc: 0.6356 - bag_output_acc: 0.5636 - footwear_output_acc: 0.5059 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7122 - val_loss: 7.9261 - val_gender_output_loss: 0.6843 - val_image_quality_output_loss: 1.0131 - val_age_output_loss: 1.4310 - val_weight_output_loss: 0.9792 - val_bag_output_loss: 0.9150 - val_footwear_output_loss: 1.0660 - val_pose_output_loss: 0.9276 - val_emotion_output_loss: 0.9099 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 10/30
# 360/360 [==============================] - 53s 148ms/step - loss: 7.7594 - gender_output_loss: 0.6758 - image_quality_output_loss: 0.9603 - age_output_loss: 1.4185 - weight_output_loss: 0.9784 - bag_output_loss: 0.9118 - footwear_output_loss: 0.9861 - pose_output_loss: 0.9264 - emotion_output_loss: 0.9020 - gender_output_acc: 0.5737 - image_quality_output_acc: 0.5563 - age_output_acc: 0.3997 - weight_output_acc: 0.6354 - bag_output_acc: 0.5629 - footwear_output_acc: 0.5126 - pose_output_acc: 0.6176 - emotion_output_acc: 0.7121 - val_loss: 7.9208 - val_gender_output_loss: 0.6823 - val_image_quality_output_loss: 1.0152 - val_age_output_loss: 1.4292 - val_weight_output_loss: 0.9783 - val_bag_output_loss: 0.9138 - val_footwear_output_loss: 1.0645 - val_pose_output_loss: 0.9276 - val_emotion_output_loss: 0.9098 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 11/30
# 360/360 [==============================] - 54s 150ms/step - loss: 7.7454 - gender_output_loss: 0.6717 - image_quality_output_loss: 0.9610 - age_output_loss: 1.4170 - weight_output_loss: 0.9775 - bag_output_loss: 0.9128 - footwear_output_loss: 0.9796 - pose_output_loss: 0.9259 - emotion_output_loss: 0.8999 - gender_output_acc: 0.5707 - image_quality_output_acc: 0.5563 - age_output_acc: 0.3996 - weight_output_acc: 0.6350 - bag_output_acc: 0.5629 - footwear_output_acc: 0.5192 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7123 - val_loss: 7.9108 - val_gender_output_loss: 0.6821 - val_image_quality_output_loss: 1.0165 - val_age_output_loss: 1.4280 - val_weight_output_loss: 0.9780 - val_bag_output_loss: 0.9128 - val_footwear_output_loss: 1.0560 - val_pose_output_loss: 0.9278 - val_emotion_output_loss: 0.9096 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
#
# Epoch 12/30
# 360/360 [==============================] - 55s 154ms/step - loss: 7.7312 - gender_output_loss: 0.6692 - image_quality_output_loss: 0.9619 - age_output_loss: 1.4152 - weight_output_loss: 0.9779 - bag_output_loss: 0.9091 - footwear_output_loss: 0.9704 - pose_output_loss: 0.9260 - emotion_output_loss: 0.9016 - gender_output_acc: 0.5785 - image_quality_output_acc: 0.5561 - age_output_acc: 0.3992 - weight_output_acc: 0.6352 - bag_output_acc: 0.5661 - footwear_output_acc: 0.5176 - pose_output_acc: 0.6176 - emotion_output_acc: 0.7122 - val_loss: 7.9096 - val_gender_output_loss: 0.6821 - val_image_quality_output_loss: 1.0183 - val_age_output_loss: 1.4275 - val_weight_output_loss: 0.9784 - val_bag_output_loss: 0.9128 - val_footwear_output_loss: 1.0525 - val_pose_output_loss: 0.9280 - val_emotion_output_loss: 0.9099 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.3785 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 13/30
# 360/360 [==============================] - 54s 151ms/step - loss: 7.7141 - gender_output_loss: 0.6625 - image_quality_output_loss: 0.9591 - age_output_loss: 1.4165 - weight_output_loss: 0.9758 - bag_output_loss: 0.9100 - footwear_output_loss: 0.9649 - pose_output_loss: 0.9253 - emotion_output_loss: 0.8999 - gender_output_acc: 0.5828 - image_quality_output_acc: 0.5567 - age_output_acc: 0.3997 - weight_output_acc: 0.6348 - bag_output_acc: 0.5647 - footwear_output_acc: 0.5223 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7124 - val_loss: 7.9043 - val_gender_output_loss: 0.6824 - val_image_quality_output_loss: 1.0184 - val_age_output_loss: 1.4251 - val_weight_output_loss: 0.9780 - val_bag_output_loss: 0.9127 - val_footwear_output_loss: 1.0502 - val_pose_output_loss: 0.9284 - val_emotion_output_loss: 0.9091 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 14/30
# 360/360 [==============================] - 54s 149ms/step - loss: 7.7163 - gender_output_loss: 0.6666 - image_quality_output_loss: 0.9595 - age_output_loss: 1.4139 - weight_output_loss: 0.9783 - bag_output_loss: 0.9099 - footwear_output_loss: 0.9639 - pose_output_loss: 0.9254 - emotion_output_loss: 0.8989 - gender_output_acc: 0.5762 - image_quality_output_acc: 0.5566 - age_output_acc: 0.3990 - weight_output_acc: 0.6349 - bag_output_acc: 0.5633 - footwear_output_acc: 0.5250 - pose_output_acc: 0.6177 - emotion_output_acc: 0.7122 - val_loss: 7.9031 - val_gender_output_loss: 0.6823 - val_image_quality_output_loss: 1.0198 - val_age_output_loss: 1.4238 - val_weight_output_loss: 0.9768 - val_bag_output_loss: 0.9125 - val_footwear_output_loss: 1.0495 - val_pose_output_loss: 0.9283 - val_emotion_output_loss: 0.9101 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 15/30
# Epoch 14/30
# 359/360 [============================>.] - ETA: 0s - loss: 7.6862 - gender_output_loss: 0.6574 - image_quality_output_loss: 0.9548 - age_output_loss: 1.4115 - weight_output_loss: 0.9759 - bag_output_loss: 0.9062 - footwear_output_loss: 0.9564 - pose_output_loss: 0.9248 - emotion_output_loss: 0.8993 - gender_output_acc: 0.5880 - image_quality_output_acc: 0.5556 - age_output_acc: 0.4000 - weight_output_acc: 0.6355 - bag_output_acc: 0.5680 - footwear_output_acc: 0.5259 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7121Epoch 15/30
# 360/360 [==============================] - 54s 151ms/step - loss: 7.6869 - gender_output_loss: 0.6574 - image_quality_output_loss: 0.9554 - age_output_loss: 1.4112 - weight_output_loss: 0.9760 - bag_output_loss: 0.9063 - footwear_output_loss: 0.9567 - pose_output_loss: 0.9249 - emotion_output_loss: 0.8989 - gender_output_acc: 0.5883 - image_quality_output_acc: 0.5552 - age_output_acc: 0.4004 - weight_output_acc: 0.6353 - bag_output_acc: 0.5678 - footwear_output_acc: 0.5258 - pose_output_acc: 0.6180 - emotion_output_acc: 0.7122 - val_loss: 7.9045 - val_gender_output_loss: 0.6825 - val_image_quality_output_loss: 1.0217 - val_age_output_loss: 1.4231 - val_weight_output_loss: 0.9767 - val_bag_output_loss: 0.9126 - val_footwear_output_loss: 1.0501 - val_pose_output_loss: 0.9282 - val_emotion_output_loss: 0.9097 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 16/30
# 359/360 [============================>.] - ETA: 0s - loss: 7.6825 - gender_output_loss: 0.6553 - image_quality_output_loss: 0.9543 - age_output_loss: 1.4111 - weight_output_loss: 0.9760 - bag_output_loss: 0.9056 - footwear_output_loss: 0.9567 - pose_output_loss: 0.9244 - emotion_output_loss: 0.8990 - gender_output_acc: 0.5891 - image_quality_output_acc: 0.5564 - age_output_acc: 0.3993 - weight_output_acc: 0.6350 - bag_output_acc: 0.5660 - footwear_output_acc: 0.5204 - pose_output_acc: 0.6177 - emotion_output_acc: 0.7125
# 360/360 [==============================] - 54s 150ms/step - loss: 7.6817 - gender_output_loss: 0.6554 - image_quality_output_loss: 0.9546 - age_output_loss: 1.4111 - weight_output_loss: 0.9754 - bag_output_loss: 0.9055 - footwear_output_loss: 0.9565 - pose_output_loss: 0.9243 - emotion_output_loss: 0.8990 - gender_output_acc: 0.5891 - image_quality_output_acc: 0.5563 - age_output_acc: 0.3990 - weight_output_acc: 0.6352 - bag_output_acc: 0.5661 - footwear_output_acc: 0.5206 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7125 - val_loss: 7.9043 - val_gender_output_loss: 0.6827 - val_image_quality_output_loss: 1.0236 - val_age_output_loss: 1.4229 - val_weight_output_loss: 0.9765 - val_bag_output_loss: 0.9124 - val_footwear_output_loss: 1.0479 - val_pose_output_loss: 0.9285 - val_emotion_output_loss: 0.9098 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 17/30
# 360/360 [==============================] - 55s 151ms/step - loss: 7.6716 - gender_output_loss: 0.6533 - image_quality_output_loss: 0.9501 - age_output_loss: 1.4110 - weight_output_loss: 0.9753 - bag_output_loss: 0.9040 - footwear_output_loss: 0.9542 - pose_output_loss: 0.9242 - emotion_output_loss: 0.8994 - gender_output_acc: 0.5855 - image_quality_output_acc: 0.5569 - age_output_acc: 0.3993 - weight_output_acc: 0.6352 - bag_output_acc: 0.5655 - footwear_output_acc: 0.5305 - pose_output_acc: 0.6176 - emotion_output_acc: 0.7123 - val_loss: 7.9067 - val_gender_output_loss: 0.6829 - val_image_quality_output_loss: 1.0258 - val_age_output_loss: 1.4227 - val_weight_output_loss: 0.9770 - val_bag_output_loss: 0.9126 - val_footwear_output_loss: 1.0474 - val_pose_output_loss: 0.9287 - val_emotion_output_loss: 0.9097 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 18/30
# 360/360 [==============================] - 54s 149ms/step - loss: 7.6689 - gender_output_loss: 0.6522 - image_quality_output_loss: 0.9482 - age_output_loss: 1.4079 - weight_output_loss: 0.9745 - bag_output_loss: 0.9079 - footwear_output_loss: 0.9538 - pose_output_loss: 0.9247 - emotion_output_loss: 0.8997 - gender_output_acc: 0.5877 - image_quality_output_acc: 0.5554 - age_output_acc: 0.3984 - weight_output_acc: 0.6346 - bag_output_acc: 0.5636 - footwear_output_acc: 0.5265 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7123 - val_loss: 7.9036 - val_gender_output_loss: 0.6829 - val_image_quality_output_loss: 1.0259 - val_age_output_loss: 1.4218 - val_weight_output_loss: 0.9753 - val_bag_output_loss: 0.9125 - val_footwear_output_loss: 1.0471 - val_pose_output_loss: 0.9287 - val_emotion_output_loss: 0.9093 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 19/30
# 359/360 [============================>.] - ETA: 0s - loss: 7.6590 - gender_output_loss: 0.6503 - image_quality_output_loss: 0.9524 - age_output_loss: 1.4087 - weight_output_loss: 0.9740 - bag_output_loss: 0.9024 - footwear_output_loss: 0.9502 - pose_output_loss: 0.9225 - emotion_output_loss: 0.8985 - gender_output_acc: 0.5869 - image_quality_output_acc: 0.5579 - age_output_acc: 0.3986 - weight_output_acc: 0.6352 - bag_output_acc: 0.5729 - footwear_output_acc: 0.5272 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7118Epoch 19/30
# 360/360 [==============================] - 54s 151ms/step - loss: 7.6581 - gender_output_loss: 0.6504 - image_quality_output_loss: 0.9519 - age_output_loss: 1.4087 - weight_output_loss: 0.9740 - bag_output_loss: 0.9021 - footwear_output_loss: 0.9504 - pose_output_loss: 0.9225 - emotion_output_loss: 0.8981 - gender_output_acc: 0.5869 - image_quality_output_acc: 0.5583 - age_output_acc: 0.3988 - weight_output_acc: 0.6351 - bag_output_acc: 0.5727 - footwear_output_acc: 0.5268 - pose_output_acc: 0.6180 - emotion_output_acc: 0.7120 - val_loss: 7.9020 - val_gender_output_loss: 0.6830 - val_image_quality_output_loss: 1.0254 - val_age_output_loss: 1.4213 - val_weight_output_loss: 0.9751 - val_bag_output_loss: 0.9124 - val_footwear_output_loss: 1.0463 - val_pose_output_loss: 0.9289 - val_emotion_output_loss: 0.9095 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 20/30
# 360/360 [==============================] - 54s 151ms/step - loss: 7.6498 - gender_output_loss: 0.6470 - image_quality_output_loss: 0.9457 - age_output_loss: 1.4082 - weight_output_loss: 0.9744 - bag_output_loss: 0.9055 - footwear_output_loss: 0.9479 - pose_output_loss: 0.9230 - emotion_output_loss: 0.8980 - gender_output_acc: 0.5970 - image_quality_output_acc: 0.5550 - age_output_acc: 0.3980 - weight_output_acc: 0.6352 - bag_output_acc: 0.5645 - footwear_output_acc: 0.5359 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7121 - val_loss: 7.9021 - val_gender_output_loss: 0.6830 - val_image_quality_output_loss: 1.0252 - val_age_output_loss: 1.4211 - val_weight_output_loss: 0.9752 - val_bag_output_loss: 0.9130 - val_footwear_output_loss: 1.0463 - val_pose_output_loss: 0.9291 - val_emotion_output_loss: 0.9093 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 21/30
# 360/360 [==============================] - 54s 150ms/step - loss: 7.6594 - gender_output_loss: 0.6522 - image_quality_output_loss: 0.9483 - age_output_loss: 1.4095 - weight_output_loss: 0.9758 - bag_output_loss: 0.9061 - footwear_output_loss: 0.9477 - pose_output_loss: 0.9237 - emotion_output_loss: 0.8961 - gender_output_acc: 0.5934 - image_quality_output_acc: 0.5570 - age_output_acc: 0.3993 - weight_output_acc: 0.6353 - bag_output_acc: 0.5686 - footwear_output_acc: 0.5309 - pose_output_acc: 0.6176 - emotion_output_acc: 0.7124 - val_loss: 7.9058 - val_gender_output_loss: 0.6824 - val_image_quality_output_loss: 1.0273 - val_age_output_loss: 1.4214 - val_weight_output_loss: 0.9755 - val_bag_output_loss: 0.9126 - val_footwear_output_loss: 1.0480 - val_pose_output_loss: 0.9288 - val_emotion_output_loss: 0.9098 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 22/30
# 360/360 [==============================] - 55s 152ms/step - loss: 7.6341 - gender_output_loss: 0.6456 - image_quality_output_loss: 0.9437 - age_output_loss: 1.4074 - weight_output_loss: 0.9737 - bag_output_loss: 0.9045 - footwear_output_loss: 0.9402 - pose_output_loss: 0.9224 - emotion_output_loss: 0.8966 - gender_output_acc: 0.6023 - image_quality_output_acc: 0.5573 - age_output_acc: 0.4005 - weight_output_acc: 0.6353 - bag_output_acc: 0.5715 - footwear_output_acc: 0.5377 - pose_output_acc: 0.6184 - emotion_output_acc: 0.7120 - val_loss: 7.9059 - val_gender_output_loss: 0.6822 - val_image_quality_output_loss: 1.0280 - val_age_output_loss: 1.4220 - val_weight_output_loss: 0.9753 - val_bag_output_loss: 0.9119 - val_footwear_output_loss: 1.0476 - val_pose_output_loss: 0.9284 - val_emotion_output_loss: 0.9105 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 23/30
# 359/360 [============================>.] - ETA: 0s - loss: 7.6351 - gender_output_loss: 0.6444 - image_quality_output_loss: 0.9454 - age_output_loss: 1.4063 - weight_output_loss: 0.9735 - bag_output_loss: 0.9020 - footwear_output_loss: 0.9431 - pose_output_loss: 0.9236 - emotion_output_loss: 0.8968 - gender_output_acc: 0.5995 - image_quality_output_acc: 0.5564 - age_output_acc: 0.3998 - weight_output_acc: 0.6353 - bag_output_acc: 0.5682 - footwear_output_acc: 0.5356 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7125Epoch 23/30
# 360/360 [==============================] - 54s 151ms/step - loss: 7.6353 - gender_output_loss: 0.6446 - image_quality_output_loss: 0.9454 - age_output_loss: 1.4057 - weight_output_loss: 0.9740 - bag_output_loss: 0.9019 - footwear_output_loss: 0.9428 - pose_output_loss: 0.9235 - emotion_output_loss: 0.8975 - gender_output_acc: 0.5990 - image_quality_output_acc: 0.5563 - age_output_acc: 0.4002 - weight_output_acc: 0.6352 - bag_output_acc: 0.5687 - footwear_output_acc: 0.5359 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7122 - val_loss: 7.9060 - val_gender_output_loss: 0.6832 - val_image_quality_output_loss: 1.0280 - val_age_output_loss: 1.4217 - val_weight_output_loss: 0.9749 - val_bag_output_loss: 0.9120 - val_footwear_output_loss: 1.0467 - val_pose_output_loss: 0.9289 - val_emotion_output_loss: 0.9105 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 24/30
# 360/360 [==============================] - 55s 153ms/step - loss: 7.6187 - gender_output_loss: 0.6442 - image_quality_output_loss: 0.9374 - age_output_loss: 1.4056 - weight_output_loss: 0.9741 - bag_output_loss: 0.9040 - footwear_output_loss: 0.9372 - pose_output_loss: 0.9221 - emotion_output_loss: 0.8939 - gender_output_acc: 0.6020 - image_quality_output_acc: 0.5586 - age_output_acc: 0.3998 - weight_output_acc: 0.6350 - bag_output_acc: 0.5688 - footwear_output_acc: 0.5363 - pose_output_acc: 0.6180 - emotion_output_acc: 0.7124 - val_loss: 7.9124 - val_gender_output_loss: 0.6822 - val_image_quality_output_loss: 1.0335 - val_age_output_loss: 1.4218 - val_weight_output_loss: 0.9751 - val_bag_output_loss: 0.9120 - val_footwear_output_loss: 1.0475 - val_pose_output_loss: 0.9293 - val_emotion_output_loss: 0.9111 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 25/30
# 360/360 [==============================] - 54s 151ms/step - loss: 7.6218 - gender_output_loss: 0.6398 - image_quality_output_loss: 0.9401 - age_output_loss: 1.4064 - weight_output_loss: 0.9741 - bag_output_loss: 0.9010 - footwear_output_loss: 0.9426 - pose_output_loss: 0.9222 - emotion_output_loss: 0.8956 - gender_output_acc: 0.6082 - image_quality_output_acc: 0.5566 - age_output_acc: 0.3970 - weight_output_acc: 0.6352 - bag_output_acc: 0.5702 - footwear_output_acc: 0.5371 - pose_output_acc: 0.6177 - emotion_output_acc: 0.7124 - val_loss: 7.9126 - val_gender_output_loss: 0.6824 - val_image_quality_output_loss: 1.0347 - val_age_output_loss: 1.4216 - val_weight_output_loss: 0.9746 - val_bag_output_loss: 0.9119 - val_footwear_output_loss: 1.0481 - val_pose_output_loss: 0.9292 - val_emotion_output_loss: 0.9101 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 26/30
# 360/360 [==============================] - 54s 150ms/step - loss: 7.6157 - gender_output_loss: 0.6366 - image_quality_output_loss: 0.9439 - age_output_loss: 1.4073 - weight_output_loss: 0.9725 - bag_output_loss: 0.9011 - footwear_output_loss: 0.9348 - pose_output_loss: 0.9226 - emotion_output_loss: 0.8969 - gender_output_acc: 0.6073 - image_quality_output_acc: 0.5564 - age_output_acc: 0.4024 - weight_output_acc: 0.6357 - bag_output_acc: 0.5701 - footwear_output_acc: 0.5367 - pose_output_acc: 0.6179 - emotion_output_acc: 0.7122 - val_loss: 7.9102 - val_gender_output_loss: 0.6830 - val_image_quality_output_loss: 1.0321 - val_age_output_loss: 1.4213 - val_weight_output_loss: 0.9750 - val_bag_output_loss: 0.9123 - val_footwear_output_loss: 1.0474 - val_pose_output_loss: 0.9295 - val_emotion_output_loss: 0.9096 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 27/30
# 360/360 [==============================] - 54s 150ms/step - loss: 7.6298 - gender_output_loss: 0.6408 - image_quality_output_loss: 0.9477 - age_output_loss: 1.4073 - weight_output_loss: 0.9726 - bag_output_loss: 0.9023 - footwear_output_loss: 0.9400 - pose_output_loss: 0.9238 - emotion_output_loss: 0.8954 - gender_output_acc: 0.6008 - image_quality_output_acc: 0.5574 - age_output_acc: 0.4001 - weight_output_acc: 0.6351 - bag_output_acc: 0.5686 - footwear_output_acc: 0.5298 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7127 - val_loss: 7.9050 - val_gender_output_loss: 0.6834 - val_image_quality_output_loss: 1.0284 - val_age_output_loss: 1.4208 - val_weight_output_loss: 0.9749 - val_bag_output_loss: 0.9119 - val_footwear_output_loss: 1.0471 - val_pose_output_loss: 0.9289 - val_emotion_output_loss: 0.9095 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 28/30
# 360/360 [==============================] - 54s 150ms/step - loss: 7.6121 - gender_output_loss: 0.6353 - image_quality_output_loss: 0.9428 - age_output_loss: 1.4061 - weight_output_loss: 0.9745 - bag_output_loss: 0.9016 - footwear_output_loss: 0.9346 - pose_output_loss: 0.9211 - emotion_output_loss: 0.8962 - gender_output_acc: 0.5992 - image_quality_output_acc: 0.5562 - age_output_acc: 0.3995 - weight_output_acc: 0.6356 - bag_output_acc: 0.5737 - footwear_output_acc: 0.5391 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7123 - val_loss: 7.9052 - val_gender_output_loss: 0.6841 - val_image_quality_output_loss: 1.0282 - val_age_output_loss: 1.4208 - val_weight_output_loss: 0.9754 - val_bag_output_loss: 0.9119 - val_footwear_output_loss: 1.0471 - val_pose_output_loss: 0.9289 - val_emotion_output_loss: 0.9088 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 29/30
# 359/360 [============================>.] - ETA: 0s - loss: 7.6359 - gender_output_loss: 0.6439 - image_quality_output_loss: 0.9433 - age_output_loss: 1.4047 - weight_output_loss: 0.9722 - bag_output_loss: 0.9027 - footwear_output_loss: 0.9498 - pose_output_loss: 0.9228 - emotion_output_loss: 0.8966 - gender_output_acc: 0.5983 - image_quality_output_acc: 0.5585 - age_output_acc: 0.4001 - weight_output_acc: 0.6350 - bag_output_acc: 0.5718 - footwear_output_acc: 0.5248 - pose_output_acc: 0.6174 - emotion_output_acc: 0.7120Epoch 29/30
# 360/360 [==============================] - 54s 151ms/step - loss: 7.6351 - gender_output_loss: 0.6439 - image_quality_output_loss: 0.9432 - age_output_loss: 1.4050 - weight_output_loss: 0.9719 - bag_output_loss: 0.9028 - footwear_output_loss: 0.9496 - pose_output_loss: 0.9224 - emotion_output_loss: 0.8963 - gender_output_acc: 0.5979 - image_quality_output_acc: 0.5585 - age_output_acc: 0.3999 - weight_output_acc: 0.6353 - bag_output_acc: 0.5715 - footwear_output_acc: 0.5250 - pose_output_acc: 0.6178 - emotion_output_acc: 0.7122 - val_loss: 7.9028 - val_gender_output_loss: 0.6842 - val_image_quality_output_loss: 1.0266 - val_age_output_loss: 1.4201 - val_weight_output_loss: 0.9753 - val_bag_output_loss: 0.9122 - val_footwear_output_loss: 1.0465 - val_pose_output_loss: 0.9288 - val_emotion_output_loss: 0.9091 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117
# Epoch 30/30
# 360/360 [==============================] - 54s 149ms/step - loss: 7.6203 - gender_output_loss: 0.6378 - image_quality_output_loss: 0.9436 - age_output_loss: 1.4075 - weight_output_loss: 0.9742 - bag_output_loss: 0.9026 - footwear_output_loss: 0.9384 - pose_output_loss: 0.9210 - emotion_output_loss: 0.8952 - gender_output_acc: 0.5999 - image_quality_output_acc: 0.5574 - age_output_acc: 0.4006 - weight_output_acc: 0.6357 - bag_output_acc: 0.5680 - footwear_output_acc: 0.5372 - pose_output_acc: 0.6181 - emotion_output_acc: 0.7124 - val_loss: 7.9029 - val_gender_output_loss: 0.6834 - val_image_quality_output_loss: 1.0274 - val_age_output_loss: 1.4204 - val_weight_output_loss: 0.9749 - val_bag_output_loss: 0.9121 - val_footwear_output_loss: 1.0458 - val_pose_output_loss: 0.9293 - val_emotion_output_loss: 0.9096 - val_gender_output_acc: 0.5741 - val_image_quality_output_acc: 0.5368 - val_age_output_acc: 0.3957 - val_weight_output_acc: 0.6396 - val_bag_output_acc: 0.5736 - val_footwear_output_acc: 0.4335 - val_pose_output_acc: 0.6149 - val_emotion_output_acc: 0.7117

# %%
model
